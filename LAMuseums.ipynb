# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
museum_filepath = "./museum_visitors.csv"
museum_data = pd.read_csv(museum_filepath, index_col="Date", parse_dates=True)

# %%
# Review the data
museum_data.tail(6)
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-06-01        22171              4635                     2518
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-06-01                                  4694
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
museum_data.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
# line chart using seaborn
# define size of plot
plt.figure(figsize=(12,6))

#load the data onto seaborn
sns.lineplot(data=museum_data)

plt.title("Monthly Viditors to Los Angeles City Museums")
# Out:
# Text(0.5, 1.0, 'Monthly Viditors to Los Angeles City Museums')

# %%
# Monthly visitors to Avila Adobe
plt.figure(figsize=(12,6))

sns.lineplot(data=museum_data['Avila Adobe'])

plt.title("Monthly Visitors To Avila Adobe")
# Out:
# Text(0.5, 1.0, 'Monthly Visitors To Avila Adobe')
